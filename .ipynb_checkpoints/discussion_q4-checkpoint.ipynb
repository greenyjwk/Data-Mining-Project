# %%
from scipy.io import arff
import pandas as pd
import numpy as np


data = arff.loadarff('segment-challenge.arff')

# print(data[0].shape)
# print(type(data[0]))
# print(df.shape)

df = pd.DataFrame(data[0])

# print( df["hue-mean"][6]  )
# print( "\n" )

# type(df[i][0] ) != float64

# if not isinstance(type(df["class"][0] ), np.float64):
#     print("yeah")


# Removing the outliers
def removeOutliers(data, col):
    
    Q3 = np.quantile(data[col], 0.75)
    Q1 = np.quantile(data[col], 0.25)
    IQR = Q3 - Q1

    print("\n")
    print("=========")
    print("Q1 : " , Q1)
    print("Q3 : " , Q3)
    print("IQR value for column %s is: %s" % (col, IQR))
    print("=========")
    print("\n")
#     global outlier_free_list
    global filtered_data
 
    lower_range = Q1 - 1.5 * IQR
    upper_range = Q3 + 1.5 * IQR    
    
    outlier_has_list = []
    for x in data[col]: 
#         print(data[col])
        if ((x < lower_range) | (x > upper_range)):
            outlier_has_list.append(x)
    print(outlier_has_list)
    print("length : ", len(outlier_has_list))
  



def remove_outlier_IQR(df):
    Q1=df.quantile(0.25)
    Q3=df.quantile(0.75)
    IQR=Q3-Q1
    df_final=df[((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR)))]
    return df_final


def remove_outlier_IQR2(data, col):    
    print("\n")
    print("=========")
    print("Q1 : " , Q1)
    print("Q3 : " , Q3)
    print("IQR value for column %s is: %s" % (col, IQR))
    print("=========")
    print("\n")
    
    outlier_has_list = []
    for x in data[col]: 
#         print(data[col])
        if ((x < lower_range) | (x > upper_range)):
            outlier_has_list.append(x)
    print(outlier_has_list)
    print("length : ", len(outlier_has_list))


temp = remove_outlier_IQR(df)


for i in df.columns:
    if i == "class":
        print("This is not continuous attribute data")
 




# outlier_has_list = [x for x in data[col] if ((x < lower_range) | (x > upper_range))]
#     if len(outlier_has_list) > 0:
#         print(outlier_has_list)
#     filtered_data = data.loc[data[col].isin(outlier_free_list)]
 
    
# for i in df.columns:
#     if i == "class":
#         print("This is not continuous attribute data")
#     else:
#         removeOutliers(df, i)
 
  
# Assigning filtered data back to our original variable
data = filtered_data
print("Shape of data after outlier removal is: ", data.shape)
# Out:
# This is not continuous attribute data
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-137-44ad2ce668db> in <module>
#     103
#     104 # Assigning filtered data back to our original variable
# --> 105 data = filtered_data
#     106 print("Shape of data after outlier removal is: ", data.shape)
#
# NameError: name 'filtered_data' is not defined

# %%
from scipy.io import arff
import pandas as pd
import numpy as np


data = arff.loadarff('segment-challenge.arff')
df = pd.DataFrame(data[0])


def detect_outlier_IQR(df):
    Q1=df.quantile(0.25)
    Q3=df.quantile(0.75)
    IQR=Q3-Q1
    df_final=df[((df<(Q1-1.5*IQR)) | (df>(Q3+1.5*IQR)))]
    return df_final
    
    
for i in df.columns:
    allData = detect_outlier_IQR(df)
    temp2 = allData[i]
    tempw = temp2[-np.isnan(temp2)]
    print(f"The number of {i} outlier is : ", len(tt))
# Out:
# The number of region-centroid-col outlier is :  0
# The number of region-centroid-row outlier is :  0
# The number of region-pixel-count outlier is :  0
# The number of short-line-density-5 outlier is :  189
# The number of short-line-density-2 outlier is :  62
# The number of vedge-mean outlier is :  94
# The number of vegde-sd outlier is :  132
# The number of hedge-mean outlier is :  141
# The number of hedge-sd outlier is :  161
# The number of intensity-mean outlier is :  59
# The number of rawred-mean outlier is :  101
# The number of rawblue-mean outlier is :  0
# The number of rawgreen-mean outlier is :  121
# The number of exred-mean outlier is :  44
# The number of exblue-mean outlier is :  0
# The number of exgreen-mean outlier is :  31
# The number of value-mean outlier is :  0
# The number of saturation-mean outlier is :  102
# The number of hue-mean outlier is :  244
# ---------------------------------------------------------------------------
# ...

# %%
from scipy.io import arff
import pandas as pd
import numpy as np

from collections import Counter 

data = arff.loadarff('segment-challenge.arff')

# print(data[0].shape)
# print(type(data[0]))
df = pd.DataFrame(data[0])

# print(df.shape)
# print(df.head)
# print(df)


def detect_outliers(df, n, features): 
    outlier_indices = [] 
    for col in features: 
        Q1 = np.percentile(df[col], 25) 
        Q3 = np.percentile(df[col], 75) 
        IQR = Q3 - Q1 
        print(IQR)
        
        outlier_step = 1.5 * IQR 
        outlier_list_col = df[(df[col] < Q1 - outlier_step) | (df[col] > Q3 + outlier_step)].index 
        outlier_indices.extend(outlier_list_col) 
    
    outlier_indices = Counter(outlier_indices)     
#     multiple_outliers = list(k for k, v in outlier_indices.items() if v > n) 
        
    return multiple_outliers 

Outliers_to_drop = detect_outliers(df, 2, ["class", "hue-mean"])
print(Outliers_to_drop)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-954fa5273436> in <module>
#      33     return multiple_outliers
#      34
# ---> 35 Outliers_to_drop = detect_outliers(df, 2, ["class", "hue-mean"])
#      36 print(Outliers_to_drop)
#      37
#
# <ipython-input-10-954fa5273436> in detect_outliers(df, n, features)
#      19     outlier_indices = []
#      20     for col in features:
# ---> 21         Q1 = np.percentile(df[col], 25)
#      22         Q3 = np.percentile(df[col], 75)
#      23         IQR = Q3 - Q1
#
# <__array_function__ internals> in percentile(*args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/numpy/lib/function_base.py in percentile(a, q, axis, out, overwrite_input, interpolation, keepdims)
#    3730     if not _quantile_is_valid(q):
#    3731         raise ValueError("Percentiles must be in the range [0, 100]")
# ...
